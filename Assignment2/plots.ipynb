# %%
from matplotlib import pyplot as mp
import numpy as np

def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

x_values = np.linspace(-3, 3, 120)
for mu, sig in [(0.2741874250318828, 0.0759094519579517), (0.6668274576094989, 0.12454589307050082)]:
    mp.plot(x_values, gaussian(x_values, mu, sig))

mp.show()

# %%
from matplotlib import pyplot as mp
import numpy as np

def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

x_values = np.linspace(-3, 3, 120)
for mu, sig in [(0.5917033401725591, 0.06755978988313717), (0.2904415550899382, 0.08461119524357369), (0.8005173012201164, 0.02636812112136855)]:
    mp.plot(x_values, gaussian(x_values, mu, sig))

mp.show()

# %%
from matplotlib import pyplot as mp
import numpy as np

def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

x_values = np.linspace(-3, 3, 120)
for mu, sig in [(0.8006294707723726, 0.02626650205824097), (0.5974440989279265, 0.07034247467133195), (0.2906300660677391, 0.0847341955284688), (0.5821172134906654,0.06190101376888209)]:
    mp.plot(x_values, gaussian(x_values, mu, sig))

mp.show()
